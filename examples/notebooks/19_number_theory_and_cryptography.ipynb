# %% [markdown]
# # URAE Tutorial: Number Theory, Elliptic Curves & RSA
#
# Demonstrates algebraic number theory algorithms:
# - Modular exponentiation and multiplicative inverse
# - Elliptic curve group law $y^2 = x^3 + ax + b \pmod p$
# - Pollard rho integer factorization

# %%
import urae

p = 6277101735386680763835789423207666416083908700390324961279
print("Prime test:", urae.is_prime(p))
print("Modular inverse:", urae.mod_inverse(17, 3120))
print("Pollard rho factor:", urae.pollard_rho(10403))
